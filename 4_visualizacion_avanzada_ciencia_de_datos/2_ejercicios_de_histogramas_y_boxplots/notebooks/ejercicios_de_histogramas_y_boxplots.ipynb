# %% [markdown]
# # Ejercicios de histogramas y boxplots (Core)
#
# ## Análisis de Distribución y Desviaciones Usando Histogramas y Boxplots
#
# ## Objetivo
#
# El objetivo de esta actividad es desarrollar habilidades avanzadas en la visualización de datos utilizando histogramas y boxplots. Usaremos un dataset interesante de Kaggle para explorar la distribución de los datos y detectar cualquier valor atípico. Esta actividad te ayudará a entender mejor la distribución de los datos y cómo los valores atípicos pueden afectar tu análisis.
#
# ## Descripción del Ejercicio
#
# En esta actividad, utilizaremos el dataset «World Happiness Report» de Kaggle, que contiene información sobre la felicidad en diferentes países del mundo. Este dataset incluye variables como el puntaje de felicidad, el PIB per cápita, la expectativa de vida saludable, la libertad, la generosidad, entre otras.
#
# Puedes descargar el dataset desde el siguiente enlace: https://www.kaggle.com/datasets/unsdsn/world-happiness
#
# ## Instrucciones
#
# ### 1. Cargar y Explorar los Datos:
#
# * Descarga el dataset y cárgalo en un DataFrame de Pandas.
# * Realiza una exploración inicial de los datos para entender las variables disponibles.
#
# ### 2. Crear Histogramas:
#
# * Crea histogramas para las variables Score, GDP per capita, Healthy life expectancy y Freedom to make life choices.
# * Personaliza los histogramas con colores, bordes y ajustes de transparencia.
#
# ### 3. Crear Boxplots:
#
# * Crea boxplots para las mismas variables para visualizar la mediana, el rango intercuartil y los valores atípicos.
# * Personaliza los boxplots con diferentes colores y estilos.
#
# ### 4. Análisis Combinado:
#
# * Combina los histogramas y los boxplots en una sola figura para cada variable.
# * Interpreta los resultados y escribe un análisis sobre la distribución de cada variable y la presencia de valores atípicos.
#
# ## Análisis Esperado
#
# Al completar la actividad, debes escribir un análisis detallado sobre la distribución de las variables y la presencia de valores atípicos. Por ejemplo:
#
# ### Distribución del Puntaje de Felicidad:
#
# * El histograma muestra que la mayoría de los países tienen un puntaje de felicidad entre 4 y 7.
# * El boxplot revela algunos valores atípicos con puntajes muy altos o muy bajos, indicando países con niveles de felicidad extremadamente altos o bajos.
#
# ### Distribución del PIB per Cápita:
#
# * El histograma muestra una distribución sesgada hacia la derecha, lo que indica que la mayoría de los países tienen un PIB per cápita bajo, con algunos países con PIB per cápita muy alto.
# * El boxplot confirma la presencia de valores atípicos en la cola derecha de la distribución.
#
# ### Distribución de la Expectativa de Vida Saludable:
#
# * El histograma muestra una distribución relativamente simétrica con un pico alrededor de los 65 años.
# * El boxplot muestra algunos valores atípicos en ambos extremos, lo que indica variabilidad en la expectativa de vida saludable entre diferentes países.
#
# ### Distribución de la Libertad para Tomar Decisiones de Vida:
#
# * El histograma muestra una distribución sesgada hacia la derecha, similar a la del PIB per cápita.
# * El boxplot revela varios valores atípicos, indicando que en algunos países la libertad para tomar decisiones de vida es significativamente diferente de la mayoría.

# %% [markdown]
# # Resolución

# %% [markdown]
# ### Carga de datasets

# %%
import pandas as pd

camino_ds_2015 = "../data/2015.csv"
camino_ds_2016 = "../data/2016.csv"
camino_ds_2017 = "../data/2017.csv"
camino_ds_2018 = "../data/2018.csv"
camino_ds_2019 = "../data/2019.csv"

df_2015 = pd.read_csv(camino_ds_2015)
df_2016 = pd.read_csv(camino_ds_2016)
df_2017 = pd.read_csv(camino_ds_2017)
df_2018 = pd.read_csv(camino_ds_2018)
df_2019 = pd.read_csv(camino_ds_2019)

# %% [markdown]
# ### Análisis de Dataset 2015

# %%
# Visualización de cabezera
df_2015.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# #### Información de columnas
#
# * Country: Nombre del País.
# * Region: Región.
# * Happiness Rank: Puesto del país en base a su puntuación de Felicidad.
# * Happiness Score: Puntuación de felicidad del país.
# * Standard Error: El error estándar de la puntuación de felicidad.
# * Economy (GDP per Capita): Cuanto afecta el GDP per Capita en la puntuación de felicidad.
# * Family: Cuanto afecta la familia en la puntuación de felicidad.
# * Health (Life Expectancy): Cuanto afecta la salud en la puntuación de la felicidad.
# * Freedom: Como afecta la libertad en el índice de la felicidad.
# * Trust (Government Corruption): Cuanto afecta la confianza en el gobierno en la felicidad.
# * Generosity: Cuanto afecta la generosidad en la puntuación de la felicidad.
# * Dystopia Residual: La diferencia entre el valor actual y el predicho de acuerdos a los datos del dataset.
#
# Al sumar todas las columnas a partir de la economía se obtiene la puntuación de felicidad del País.

# %% [markdown]
# #### Información de la tabla

# %%
# sacamos la información de la tabla.
df_2015.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df_2015.shape
# Out:
# (158, 12)

# %% [markdown]
# #### Datos estadísticos

# %%
# sacamos datos estadísticos.
df_2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# #### Histogramas

# %%
from utils import plot_histograms

plot_histograms(df_2015)
# Out:
# /Users/diego/Documents/Programacion/ds_bootcamp/coding-dojo-ds-bootcamp/4_visualizacion_avanzada_ciencia_de_datos/2_ejercicios_de_histogramas_y_boxplots/notebooks/utils.py:13: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(

# %% [markdown]
# #### Boxplots

# %%
from utils import plot_boxplots

plot_boxplots(df_2015)

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# ##### Columna de Felicidad

# %%
from utils import plot_histogram_boxplot

plot_histogram_boxplot(df_2015, "Happiness Score", "Hapiness Score", "Frecuencia", "Hapiness Score")

# %% [markdown]
# De la gráfica se puede sacar las siguientes conclusiones:
#
# * La mayoría de los países tiene un Hapiness Score de entre 4.5 y 6.5
# * A través del boxplot, se puede ver que hay una pequeña cantidad de países que tienen o un score muy alto, o muy bajo.

# %% [markdown]
# ##### Columna de PIB per Cápita

# %%
plot_histogram_boxplot(
    df_2015, 
    "Economy (GDP per Capita)",
    "Economy (GDP per Capita)",
    "Frecuencia",
    "Economy (GDP per Capita)",
)

# %% [markdown]
# De ambas gráficas se puede notar lo siguiente:
#
# * Se puede notar del histograma que los puntajes de economía estan en su mayoría concentrados entre 0.5 y 1.25, con una tendencia de que la mayoría de los países tienen un GDP intermedio.
# * En el boxplot se puede confirmar la distribución de los datos fijándose en la mediana, y también hay anomalías en una cantidad pequeña de países con tendencias muy altas y muy bajas.

# %% [markdown]
# ##### Columna de Salud

# %%
plot_histogram_boxplot(
    df_2015, 
    "Health (Life Expectancy)",
    "Health (Life Expectancy)",
    "Frecuencia",
    "Health (Life Expectancy)",
)

# %% [markdown]
# De ambas gráficas se pude mostrar lo siguiente.
#
# * Los datos en el histograma están muy agrupados hacia el rango 0.6-0.9, lo que indica que la mayoría de países reporta un alto puntaje en salud.
# * El boxplot también es pequeño, con una mediana más alta indicando lo mencionado previamente. También, se puede notar que la dispersión es baja ya que el tamaño de la caja es grande y la mayoría de los datos entre los curtiles esta entre 0.4 y 0.8

# %% [markdown]
# ##### Columna de Freedom

# %%
plot_histogram_boxplot(
    df_2015, 
    "Freedom",
    "Freedom",
    "Frecuencia",
    "Freedom",
)

# %% [markdown]
# De los gráficos, se sacan las siguientes conclusiones:
#
# * En el histograma, se puede notar que los datos están sesgados hacia la derecha, por lo que la mayoría de los países reportan un puntaje alto de libertad.
# * En el boxplot, se puede notar que el rango intercuartil va de 0.35 a 0.55 approx. Al ser un rango pequeño comparado con los mínimos y máximos, se puede concluír que los datos tienen poca dispersión.

# %% [markdown]
# ### Análisis de Dataset 2016

# %%
# Visualización de cabezera
df_2016.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0      Denmark             Western Europe               1            7.526
# 1  Switzerland             Western Europe               2            7.509
# 2      Iceland             Western Europe               3            7.501
# 3       Norway             Western Europe               4            7.498
# 4      Finland             Western Europe               5            7.413
# 5       Canada              North America               6            7.404
# 6  Netherlands             Western Europe               7            7.339
# 7  New Zealand  Australia and New Zealand               8            7.334
# 8    Australia  Australia and New Zealand               9            7.313
# 9       Sweden             Western Europe              10            7.291
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# ...

# %% [markdown]
# #### Información de la tabla.

# %%
df_2016.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df_2016.shape
# Out:
# (157, 13)

# %% [markdown]
# #### Datos estadísticos

# %%
df_2016.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %% [markdown]
# #### Histogramas

# %%
plot_histograms(df_2016)
# Out:
# /Users/diego/Documents/Programacion/ds_bootcamp/coding-dojo-ds-bootcamp/4_visualizacion_avanzada_ciencia_de_datos/2_ejercicios_de_histogramas_y_boxplots/notebooks/utils.py:13: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(

# %% [markdown]
# #### Boxplots

# %%
plot_boxplots(df_2016)

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# ##### Columna de Felicidad

# %%
plot_histogram_boxplot(df_2016, "Happiness Score", "Hapiness Score", "Frecuencia", "Hapiness Score")

# %% [markdown]
# * En el histograma, se puede notar que los datos están un poco mejor distribuídos que en 2015, aunque de igual manera hay un pequeño sesgo hacia un mayor índice de felicidad.
# * Del boxplot, se puede notar que la dispersión no es tan alta, pero sí una pequeña cantidad de valores anómalos.

# %% [markdown]
# ##### Columna de PIB Per Cápita

# %%
plot_histogram_boxplot(
    df_2016, 
    "Economy (GDP per Capita)",
    "Economy (GDP per Capita)",
    "Frecuencia",
    "Economy (GDP per Capita)",
)

# %% [markdown]
# * En el histograma, se puede ver un sesgo de los datos hacia la derecha, indicando que la mayoría de los países reportan que el GDP per cápita influye bastante en la puntuación de felicidad.
# * Del boxplot, se puede notar que la dispersión no es tan alta, pero sí una pequeña cantidad de valores anómalos.

# %% [markdown]
# ##### Análisis de columna de salud.

# %%
plot_histogram_boxplot(
    df_2016, 
    "Health (Life Expectancy)",
    "Health (Life Expectancy)",
    "Frecuencia",
    "Health (Life Expectancy)",
)

# %% [markdown]
# De ambas gráficas se pude mostrar lo siguiente.
#
# * Los datos en el histograma están muy agrupados hacia el rango 0.5-0.9, lo que indica que la mayoría de países reporta un alto puntaje en salud.
# * El boxplot también es pequeño, con una mediana más alta indicando lo mencionado previamente. También, se puede notar que la dispersión es baja ya que el tamaño de la caja es pequeño y la mayoría de los datos entre los curtiles esta entre 0.4 y 0.75

# %% [markdown]
# ##### Columna de Freedom

# %%
plot_histogram_boxplot(
    df_2016, 
    "Freedom",
    "Freedom",
    "Frecuencia",
    "Freedom",
)

# %% [markdown]
# De los gráficos, se sacan las siguientes conclusiones:
#
# * En el histograma, se puede notar que los datos están sesgados hacia la derecha, por lo que la mayoría de los países reportan un puntaje alto de libertad.
# * En el boxplot, se puede notar que el rango intercuartil va de 0.28 a 0.5 approx. Al ser un rango pequeño comparado con los mínimos y máximos, se puede concluír que los datos tienen poca dispersión.

# %% [markdown]
# ### Análisis de Dataset 2017

# %%
# Visualización de cabezera
df_2017.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %% [markdown]
# #### Información de la tabla

# %%
# sacamos la información de la tabla.
df_2017.dtypes
# Out:
# Country                           object
# Happiness.Rank                     int64
# Happiness.Score                  float64
# Whisker.high                     float64
# Whisker.low                      float64
# Economy..GDP.per.Capita.         float64
# Family                           float64
# Health..Life.Expectancy.         float64
# Freedom                          float64
# Generosity                       float64
# Trust..Government.Corruption.    float64
# Dystopia.Residual                float64
# dtype: object

# %%
df_2017.shape
# Out:
# (155, 12)

# %% [markdown]
# #### Datos estadísticos

# %%
# sacamos datos estadísticos.
df_2017.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %%
# Renombramos campos a analizar para que las funciones de elaboración de gráficos funcionen.

df_2017.rename(
    columns={
        "Happiness.Score": "Happiness Score",
        "Economy..GDP.per.Capita.": "Economy (GDP per Capita)",
        "Health..Life.Expectancy.": "Health (Life Expectancy)",
    },
    inplace=True
)

# %% [markdown]
# #### Histogramas

# %%
plot_histograms(df_2017)
# Out:
# /Users/diego/Documents/Programacion/ds_bootcamp/coding-dojo-ds-bootcamp/4_visualizacion_avanzada_ciencia_de_datos/2_ejercicios_de_histogramas_y_boxplots/notebooks/utils.py:13: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(

# %% [markdown]
# #### Boxplots

# %%
plot_boxplots(df_2017)

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# ##### Columna de Felicidad

# %%
plot_histogram_boxplot(df_2017, "Happiness Score", "Hapiness Score", "Frecuencia", "Hapiness Score")

# %% [markdown]
# De la gráfica se puede sacar las siguientes conclusiones:
#
# * La mayoría de los países tiene un Hapiness Score distribuído un poco mejor, con la mayor cantidad concentrándose entre 4.2 a 6.1 approx.
# * A través del boxplot, se puede ver que hay una pequeña cantidad de países que tienen o un score muy alto, o muy bajo. No hay mucha dispersión en los datos.

# %% [markdown]
# ##### Columna de PIB per Cápita

# %%
plot_histogram_boxplot(
    df_2017, 
    "Economy (GDP per Capita)",
    "Economy (GDP per Capita)",
    "Frecuencia",
    "Economy (GDP per Capita)",
)

# %% [markdown]
# * En el histograma, se puede ver un sesgo de los datos hacia la derecha, indicando que la mayoría de los países reportan que el GDP per cápita influye bastante en la puntuación de felicidad.
# * Del boxplot, se puede notar que la dispersión no es tan alta, pero sí una pequeña cantidad de valores anómalos.

# %% [markdown]
# ##### Columna de Salud

# %%
plot_histogram_boxplot(
    df_2017, 
    "Health (Life Expectancy)",
    "Health (Life Expectancy)",
    "Frecuencia",
    "Health (Life Expectancy)",
)

# %% [markdown]
# De ambas gráficas se pude mostrar lo siguiente.
#
# * Los datos en el histograma indican un sesgo a la derecha, lo que indica que muchos países dan una puntuación alta a la salud
# * El boxplot también es pequeño, con una mediana más alta indicando lo mencionado previamente. También, se puede notar que la dispersión es baja ya que el tamaño de la caja es pequeña y la mayoría de los datos entre los curtiles esta entre 0.4 y 0.7

# %% [markdown]
# ##### Columna de Freedom

# %%
plot_histogram_boxplot(
    df_2017, 
    "Freedom",
    "Freedom",
    "Frecuencia",
    "Freedom",
)

# %% [markdown]
# De los gráficos, se sacan las siguientes conclusiones:
#
# * En el histograma, se puede notar que los datos están sesgados hacia la derecha, por lo que la mayoría de los países reportan un puntaje alto de libertad.
# * En el boxplot, se puede notar que el rango intercuartil va de 0.3 a 0.55 approx. Al ser un rango pequeño comparado con los mínimos y máximos, se puede concluír que los datos tienen poca dispersión.

# %% [markdown]
# ### Análisis de Dataset 2018

# %%
# Visualización de cabezera
df_2018.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# ...

# %% [markdown]
# #### Información de la tabla

# %%
# sacamos la información de la tabla.
df_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
df_2018.shape
# Out:
# (156, 9)

# %% [markdown]
# #### Datos estadísticos

# %%
# sacamos datos estadísticos.
df_2018.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
# Renombramos campos a analizar para que las funciones de elaboración de gráficos funcionen.

df_2018.rename(
    columns={
        "Score": "Happiness Score",
        "GDP per capita": "Economy (GDP per Capita)",
        "Healthy life expectancy": "Health (Life Expectancy)",
        "Freedom to make life choices": "Freedom",
    },
    inplace=True
)

# %% [markdown]
# #### Histogramas

# %%
plot_histograms(df_2018)
# Out:
# /Users/diego/Documents/Programacion/ds_bootcamp/coding-dojo-ds-bootcamp/4_visualizacion_avanzada_ciencia_de_datos/2_ejercicios_de_histogramas_y_boxplots/notebooks/utils.py:13: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(

# %% [markdown]
# #### Boxplots

# %%
plot_boxplots(df_2018)

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# #### Columna de Felicidad

# %%
plot_histogram_boxplot(df_2018, "Happiness Score", "Hapiness Score", "Frecuencia", "Hapiness Score")

# %% [markdown]
# De la gráfica se puede sacar las siguientes conclusiones:
#
# * La mayoría de los países tiene un Hapiness Score distribuído un poco mejor, con la mayor cantidad concentrándose entre 4.2 a 6.5 approx.
# * A través del boxplot, se puede ver que hay una pequeña cantidad de países que tienen o un score muy alto, o muy bajo. No hay mucha dispersión en los datos.

# %% [markdown]
# ##### Columna PIB per Cápita

# %%
plot_histogram_boxplot(
    df_2018, 
    "Economy (GDP per Capita)",
    "Economy (GDP per Capita)",
    "Frecuencia",
    "Economy (GDP per Capita)",
)

# %% [markdown]
# * En el histograma, se puede ver que la mayoría de los datos se agrupan hacia el medio, con una aparente pequeña cantidad de países que reportan un score alto de GDP Per Cápita.
# * Del boxplot, se puede notar que la dispersión no es tan alta, pero sí una pequeña cantidad de valores anómalos. También se puede visualizar un outlier con un score por encima de 2.0.

# %% [markdown]
# ##### Columna Freedom

# %%
plot_histogram_boxplot(
    df_2018, 
    "Freedom",
    "Freedom",
    "Frecuencia",
    "Freedom",
)

# %% [markdown]
# De los gráficos, se sacan las siguientes conclusiones:
#
# * En el histograma, se puede notar que los datos están sesgados hacia la derecha, por lo que la mayoría de los países reportan un puntaje alto de libertad.
# * En el boxplot, se puede notar que el rango intercuartil va de 0.35 a 0.6 approx. Al ser un rango pequeño comparado con los mínimos y máximos, se puede concluír que los datos tienen poca dispersión. También, se pueden notar outliers por debajo del valor mínimo.

# %% [markdown]
# ### Análisis de Dataset 2019

# %%
# Visualización de cabezera
df_2019.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
# Renombramos campos a analizar para que las funciones de elaboración de gráficos funcionen.

df_2019.rename(
    columns={
        "Score": "Happiness Score",
        "GDP per capita": "Economy (GDP per Capita)",
        "Healthy life expectancy": "Health (Life Expectancy)",
        "Freedom to make life choices": "Freedom"
    },
    inplace=True
)

# %% [markdown]
# #### Información de la tabla

# %%
# sacamos la información de la tabla.
df_2019.dtypes
# Out:
# Overall rank                   int64
# Country or region             object
# Happiness Score              float64
# Economy (GDP per Capita)     float64
# Social support               float64
# Health (Life Expectancy)     float64
# Freedom                      float64
# Generosity                   float64
# Perceptions of corruption    float64
# dtype: object

# %%
df_2019.shape
# Out:
# (156, 9)

# %% [markdown]
# #### Datos Estadísticos

# %%
# sacamos datos estadísticos.
df_2019.describe()
# Out:
#        Overall rank  Happiness Score  Economy (GDP per Capita)  \
# count    156.000000       156.000000                156.000000
# mean      78.500000         5.407096                  0.905147
# std       45.177428         1.113120                  0.398389
# min        1.000000         2.853000                  0.000000
# 25%       39.750000         4.544500                  0.602750
# 50%       78.500000         5.379500                  0.960000
# 75%      117.250000         6.184500                  1.232500
# max      156.000000         7.769000                  1.684000
#
#        Social support  Health (Life Expectancy)     Freedom  Generosity  \
# count      156.000000                156.000000  156.000000  156.000000
# mean         1.208814                  0.725244    0.392571    0.184846
# std          0.299191                  0.242124    0.143289    0.095254
# min          0.000000                  0.000000    0.000000    0.000000
# ...

# %% [markdown]
# #### Histogramas

# %%
plot_histograms(df_2019)
# Out:
# /Users/diego/Documents/Programacion/ds_bootcamp/coding-dojo-ds-bootcamp/4_visualizacion_avanzada_ciencia_de_datos/2_ejercicios_de_histogramas_y_boxplots/notebooks/utils.py:13: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(

# %% [markdown]
# #### Boxplots

# %%
plot_boxplots(df_2019)

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# ##### Columna de Felicidad

# %%
plot_histogram_boxplot(df_2019, "Happiness Score", "Hapiness Score", "Frecuencia", "Hapiness Score")

# %% [markdown]
# De la gráfica se puede sacar las siguientes conclusiones:
#
# * La mayoría de los países tiene un Hapiness Score distribuído un poco mejor, con la mayor cantidad concentrándose entre 4.2 a 6.1 approx.
# * A través del boxplot, se puede ver que hay una pequeña cantidad de países que tienen o un score muy alto, o muy bajo. No hay mucha dispersión en los datos.

# %% [markdown]
# ##### Columna PIB per Cápita

# %%
plot_histogram_boxplot(
    df_2019, 
    "Economy (GDP per Capita)",
    "Economy (GDP per Capita)",
    "Frecuencia",
    "Economy (GDP per Capita)",
)

# %% [markdown]
# * En el histograma, se puede ver un sesgo de los datos hacia la derecha, indicando que la mayoría de los países reportan que el GDP per cápita influye bastante en la puntuación de felicidad.
# * Del boxplot, se puede notar que la dispersión no es tan alta, pero sí una pequeña cantidad de valores anómalos.

# %% [markdown]
# ##### Columna de Salud

# %%
plot_histogram_boxplot(
    df_2019, 
    "Health (Life Expectancy)",
    "Health (Life Expectancy)",
    "Frecuencia",
    "Health (Life Expectancy)",
)

# %% [markdown]
# De ambas gráficas se pude mostrar lo siguiente.
#
# * Los datos en el histograma indican un sesgo a la derecha, lo que indica que muchos países dan una puntuación alta a la salud.
# * El boxplot también es pequeño, con una mediana más alta indicando lo mencionado previamente. También, se puede notar que la dispersión es baja ya que el tamaño de la caja es pequeña y la mayoría de los datos entre los curtiles esta entre 0.4 y 0.7. La mediana es bastante alta. Finalmente, se puede notar un outlier que tal vez sea un error, de un país que reportó una puntuación muy baja, approx 0.0 en salud.

# %%
# Verificamos el outlier para ver que valor es
df_2019.sort_values(by="Health (Life Expectancy)", ascending=True)
# Out:
#      Overall rank         Country or region  Happiness Score  \
# 134           135                 Swaziland            4.212
# 154           155  Central African Republic            3.083
# 143           144                   Lesotho            3.802
# 131           132                      Chad            4.350
# 98             99               Ivory Coast            4.944
# ..            ...                       ...              ...
# 5               6               Switzerland            7.480
# 29             30                     Spain            6.354
# 57             58                     Japan            5.886
# 75             76                 Hong Kong            5.430
# 33             34                 Singapore            6.262
#
#      Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 134                     0.811           1.149                     0.000
# 154                     0.026           0.000                     0.105
# ...

# %% [markdown]
# Se puede ver que efectivamente el outlier tiene un valor de 0.0 y corresponde a Swaziland.

# %% [markdown]
# ##### Columna de Freedom

# %%
plot_histogram_boxplot(
    df_2019, 
    "Freedom",
    "Freedom",
    "Frecuencia",
    "Freedom",
)

# %% [markdown]
# De los gráficos, se sacan las siguientes conclusiones:
#
# * En el histograma, se puede notar que los datos están sesgados hacia la derecha, por lo que la mayoría de los países reportan un puntaje alto de libertad.
# * En el boxplot, se puede notar que el rango intercuartil va de 0.3 a 0.55 approx. Al ser un rango pequeño comparado con los mínimos y máximos, se puede concluír que los datos tienen poca dispersión. También se puede identificar un outlier.

# %%
# Verificamos el outlier para ver que valor es
df_2019.sort_values(by="Freedom", ascending=True)
# Out:
#      Overall rank     Country or region  Happiness Score  \
# 153           154           Afghanistan            3.203
# 155           156           South Sudan            2.853
# 148           149                 Syria            3.462
# 146           147                 Haiti            3.597
# 121           122            Mauritania            4.490
# ..            ...                   ...              ...
# 0               1               Finland            7.769
# 20             21  United Arab Emirates            6.825
# 2               3                Norway            7.554
# 108           109              Cambodia            4.700
# 40             41            Uzbekistan            6.174
#
#      Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 153                     0.350           0.517                     0.361
# 155                     0.306           0.575                     0.295
# ...

# %% [markdown]
# Al parecer, el outlier en este caso sería Afganistán y tiene un score de libertad de 0.0.
