# %% [markdown]
# # Análisis y Predicción de Ventas en una Tienda de Retail (Core)
#
# ## Parte V: Exploración y Visualización de Datos Avanzada
#
# En esta quinta parte del proyecto, vamos a expandir nuestro análisis exploratorio de datos (EDA) y visualización utilizando técnicas avanzadas. Aplicaremos todo lo que hemos aprendido hasta ahora, incluyendo cuadrículas, leyendas, anotaciones, flechas, y subplots, para obtener una comprensión más profunda de nuestro conjunto de datos de ventas.

# %% [markdown]
# ### Instrucciones
#
# #### 1. Continuar desde la Parte IV
#
# * Asegúrate de tener el DataFrame df ya cargado y preparado desde la Parte IV.
#
# #### 2. Exploración de Datos Avanzada
#
# * Realiza un análisis de correlación y crea un mapa de calor para visualizar las relaciones entre las variables.
# * Crea subplots para comparar diferentes variables clave.
# * Añade cuadrículas, leyendas, anotaciones y flechas a tus gráficos para mejorar la claridad y la información.
#
# #### 3. Generar un Pull Request en GitHub
#
# * Generar un Tag en GitHub: Después de completar el análisis y las visualizaciones, sube los cambios a una nueva rama en tu repositorio de GitHub, genera un Pull Request (PR) para revisión y finalmente crea un tag para esta versión del proyecto.
# * Realizar una Presentación: Prepara una presentación en slides que resuma tu análisis y visualizaciones. La presentación debe incluir:
#
#     * Introducción y objetivos del proyecto.
#     * Descripción del conjunto de datos.
#     * Principales análisis y hallazgos.
#     * Visualizaciones clave con explicación.
#     * Conclusiones y recomendaciones.

# %% [markdown]
# ## Resolución Parte III

# %% [markdown]
# ### Carga de Datos
#
# Se procede a cargar los datos desde el punto en que quedó en la parte 2.

# %%
import pandas as pd

camino_dataset = "../data/retail_sales_dataset.csv"

df = pd.read_csv(camino_dataset)

# Genera estadísticas descriptivas del DataFrame utilizando el método describe().
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
# Análisis de coeficiente de variación
from eda_utils import variation_coefficient

df[["Age", "Quantity", "Price per Unit", "Total Amount"]].agg(["mean", "std", variation_coefficient])
# Out:
#                              Age  Quantity  Price per Unit  Total Amount
# mean                   41.392000  2.514000      179.890000    456.000000
# std                    13.681430  1.132734      189.681356    559.997632
# variation_coefficient   0.330533  0.450571        1.054430      1.228065

# %% [markdown]
# De estos datos, se puede determinar que la media no es un factor relevante para Quantity, Price per Unit, Total Amount. Podría influir en el caso de la edad, pero se determinaría más adelante.

# %% [markdown]
# Se analizan también los datos duplicados.

# %%
cant_datos_duplicados = df.duplicated().sum()

print(f"Cant. datos duplicados: {cant_datos_duplicados}")
# Out:
# Cant. datos duplicados: 0

# %% [markdown]
# Verificamos también si existen IDs de clientes duplicados.

# %%
cant_clientes_duplicados = df.duplicated(["Customer ID"]).sum()

print(f"Cant. clientes duplicados: {cant_clientes_duplicados}")
# Out:
# Cant. clientes duplicados: 0

# %% [markdown]
# Finalmente, también se analiza si existen datos nulos, en caso de que sirva para más adelante.

# %%
from eda_utils import obtener_estadisticas_datos_nulos

df_estadisticas = obtener_estadisticas_datos_nulos(df)

df_estadisticas
# Out:
#                   datos sin NAs en q  Na en q  Na en %
# Transaction ID                  1000        0      0.0
# Date                            1000        0      0.0
# Customer ID                     1000        0      0.0
# Gender                          1000        0      0.0
# Age                             1000        0      0.0
# Product Category                1000        0      0.0
# Quantity                        1000        0      0.0
# Price per Unit                  1000        0      0.0
# Total Amount                    1000        0      0.0

# %% [markdown]
# Al parecer, no existe ningún dato nulo en el dataset.

# %% [markdown]
# Finalmente, se procede a investigar anomalías en el dataset.

# %%
from eda_utils import obtener_estadisticas_descriptivas_df_es

obtener_estadisticas_descriptivas_df_es(df, num_decimales=2).T
# Out:
#                 Cantidad  Mínimo  Máximo  Promedio  Desviación Estándar  \
# Transaction ID    1000.0     1.0  1000.0    500.50               288.82
# Age               1000.0    18.0    64.0     41.39                13.68
# Quantity          1000.0     1.0     4.0      2.51                 1.13
# Price per Unit    1000.0    25.0   500.0    179.89               189.68
# Total Amount      1000.0    25.0  2000.0    456.00               560.00
#
#                 Mediana  Coeficiente de Variación
# Transaction ID    500.5                      0.58
# Age                42.0                      0.33
# Quantity            3.0                      0.45
# Price per Unit     50.0                      1.05
# Total Amount      135.0                      1.23

# %% [markdown]
# ### Transformación y Agregación

# %% [markdown]
# Ya existe la columna de Total Amount, pero de igual manera se agregará una nueva columna y se calculará la diferencia respecto a la columna disponible en el dataset. Esto servirá también para ver si coinciden los valores de precio por unidad y cantidades vs el monto total por venta.

# %%
df["Calculated Total Amount"] = df["Price per Unit"] * df["Quantity"]

df.head(10)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
# 5               6  2023-04-25     CUST006  Female   45           Beauty
# 6               7  2023-03-13     CUST007    Male   46         Clothing
# 7               8  2023-02-22     CUST008    Male   30      Electronics
# 8               9  2023-12-13     CUST009    Male   63      Electronics
# 9              10  2023-10-07     CUST010  Female   52         Clothing
#
#    Quantity  Price per Unit  Total Amount  Calculated Total Amount
# 0         3              50           150                      150
# 1         2             500          1000                     1000
# 2         1              30            30                       30
# 3         1             500           500                      500
# 4         2              50           100                      100
# 5         1              30            30                       30
# 6         2              25            50                       50
# 7         4              25           100                      100
# 8         2             300           600                      600
# 9         4              50           200                      200

# %% [markdown]
# Para analizar si hay una diferencia significativa entre la columna calculada y la columna de total original, se pueden restar ambas y sacar estadísticas (promedio, desviación estándar).

# %%
diferencia = abs(df["Total Amount"] - df["Calculated Total Amount"])

diferencia.agg(["mean", "std", "min", "max"])
# Out:
# mean    0.0
# std     0.0
# min     0.0
# max     0.0
# dtype: float64

# %% [markdown]
# Según las estadísticas de la columna, no existe ninguna diferencia entre la columna calculada y la del dataset.

# %% [markdown]
# Se procede a clasificar las ventas. Para esto, se toma el maximo y el mínimo de la columna Total Amount, se resta y la diferencia se divide entre 3

# %%
min_ventas = df["Total Amount"].min()
max_ventas = df["Total Amount"].max()

print(f"Valor mínimo de ventas: {min_ventas}")
print(f"Valor máximo de ventas: {max_ventas}")

diferencia = max_ventas - min_ventas

print(f"Diferencia entre max. y min.: {diferencia}")

inicio_bajas = min_ventas
# El límite de ventas bajas iría de min_ventas a limite_bajas, la cual cubre el tercio mas bajo de la diferencia.
limite_bajas = min_ventas + (float(diferencia) / 3)
# El límite de ventas medias iría de min_ventas a limite_bajas, la cual cubre el tercio mas bajo de la diferencia.
limite_medias = limite_bajas + (float(diferencia) / 3)
# El límite de ventas altas iría de limite_medias a max_ventas, la cual cubre el tercio mas bajo de la diferencia.
# También es posible usar aquí una suma similar a los otros grupos, solo que para evitar diferencias
# mínimas debido al uso de decimales, es mejor usar nada más ya max_ventas
limite_altas = max_ventas

print(f"Rango de ventas bajas: De {inicio_bajas} a {limite_bajas:.2f}")
print(f"Rango de ventas medias: De {limite_bajas:.2f} a {limite_medias:.2f}")
print(f"Rango de ventas altas: De {limite_medias:.2f} a {limite_altas}")
# Out:
# Valor mínimo de ventas: 25
# Valor máximo de ventas: 2000
# Diferencia entre max. y min.: 1975
# Rango de ventas bajas: De 25 a 683.33
# Rango de ventas medias: De 683.33 a 1341.67
# Rango de ventas altas: De 1341.67 a 2000

# %% [markdown]
# Por tanto, se crean tres grupos:
#
# * Primer grupo (Baja)
# * Segundo grupo (Media)
# * Tercer grupo (Alta)
#
# Estos grupos se incorporarán como una columna categórica en el conjunto de datos. El límite inferior de cada grupo es inclusivo, mientras que el límite superior es exclusivo.

# %%
def funcion_clasificacion(x):
    if inicio_bajas <= x["Total Amount"] < limite_bajas:
        return "Baja"
    elif limite_bajas <= x["Total Amount"] < limite_medias:
        return "Media"
    elif limite_medias <= x["Total Amount"]:
        return "Alta"


df["Sale Classification"] = df.apply(funcion_clasificacion, axis=1)
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount  Calculated Total Amount  \
# 0           3              50           150                      150
# 1           2             500          1000                     1000
# 2           1              30            30                       30
# 3           1             500           500                      500
# 4           2              50           100                      100
# ..        ...             ...           ...                      ...
# 995         1              50            50                       50
# 996         3              30            90                       90
# 997         4              25           100                      100
# 998         3              50           150                      150
# 999         4              30           120                      120
#
#     Sale Classification
# 0                  Baja
# 1                 Media
# 2                  Baja
# 3                  Baja
# 4                  Baja
# ..                  ...
# 995                Baja
# 996                Baja
# 997                Baja
# 998                Baja
# 999                Baja
#
# [1000 rows x 11 columns]

# %% [markdown]
# ### Agrupación y Agregación
#
# Se procede a agregar los grupos y a analizar los datos con agregaciones.

# %% [markdown]
# ##### Agrupación y Agregación por Género

# %%
df.groupby("Gender")["Total Amount"].agg(["mean", "std", "min", "max", variation_coefficient])
# Out:
#               mean         std  min   max  variation_coefficient
# Gender
# Female  456.549020  554.299371   25  2000               1.214107
# Male    455.428571  566.433809   25  2000               1.243738

# %%
df.groupby("Gender")["Age"].agg(["mean", "std", "min", "max", variation_coefficient])
# Out:
#              mean        std  min  max  variation_coefficient
# Gender
# Female  41.356863  13.568067   18   64               0.328073
# Male    41.428571  13.812208   18   64               0.333398

# %% [markdown]
# ##### Agrupación y Agregación por Product Category

# %%
df.groupby("Product Category")["Total Amount"].agg(["mean", "std", "min", "max", variation_coefficient])
# Out:
#                         mean         std  min   max  variation_coefficient
# Product Category
# Beauty            467.475570  563.612788   25  2000               1.205652
# Clothing          443.247863  550.695917   25  2000               1.242411
# Electronics       458.786550  567.540150   25  2000               1.237046

# %%
df.groupby("Product Category")["Age"].agg(["mean", "std", "min", "max", variation_coefficient])
# Out:
#                        mean        std  min  max  variation_coefficient
# Product Category
# Beauty            40.371336  13.889817   18   64               0.344051
# Clothing          41.948718  13.498262   18   64               0.321780
# Electronics       41.736842  13.669573   18   64               0.327518

# %% [markdown]
# #### Agrupación y Agregación por Sale Classification.

# %%
df.groupby("Sale Classification")["Total Amount"].agg(["mean", "std", "min", "max", variation_coefficient])
# Out:
#                             mean         std   min   max  \
# Sale Classification
# Alta                 1747.474747  251.259454  1500  2000
# Baja                  154.076087  157.650788    25   600
# Media                1027.878788  127.158380   900  1200
#
#                      variation_coefficient
# Sale Classification
# Alta                              0.143784
# Baja                              1.023201
# Media                             0.123710

# %% [markdown]
# En esta agrupación, se puede notar que el coeficiente de variación para las categorías alta y media son menores al 30%, por lo cual tal vez sea útil el promedio en estos casos.

# %%
df.groupby("Sale Classification")["Age"].agg(["mean", "std", "min", "max", variation_coefficient])
# Out:
#                           mean        std  min  max  variation_coefficient
# Sale Classification
# Alta                 39.202020  13.616451   18   64               0.347341
# Baja                 41.841033  13.694251   18   64               0.327292
# Media                40.703030  13.589462   18   64               0.333869

# %% [markdown]
# ### Análisis personalizado con apply.
#
# Ya se realizó un apply previamente, pero se agrega también la columna de diferencia con desviación estandar de las ventas.

# %%
std_dev = df["Total Amount"].std()

print(f"Desviación estándar {std_dev}")

df["Total Amount Stdev Difference"] = df.apply(lambda x: abs(x["Total Amount"] - std_dev), axis=1)
df
# Out:
# Desviación estándar 559.997631555123
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount  Calculated Total Amount  \
# 0           3              50           150                      150
# 1           2             500          1000                     1000
# 2           1              30            30                       30
# 3           1             500           500                      500
# 4           2              50           100                      100
# ..        ...             ...           ...                      ...
# 995         1              50            50                       50
# 996         3              30            90                       90
# 997         4              25           100                      100
# 998         3              50           150                      150
# 999         4              30           120                      120
#
#     Sale Classification  Total Amount Stdev Difference
# 0                  Baja                     409.997632
# 1                 Media                     440.002368
# 2                  Baja                     529.997632
# 3                  Baja                      59.997632
# 4                  Baja                     459.997632
# ..                  ...                            ...
# 995                Baja                     509.997632
# 996                Baja                     469.997632
# 997                Baja                     459.997632
# 998                Baja                     409.997632
# 999                Baja                     439.997632
#
# [1000 rows x 12 columns]

# %% [markdown]
# # Resolución Parte IV

# %% [markdown]
# ### Análisis Descriptivo y Visualización

# %% [markdown]
# #### Calcula estadísticas descriptivas básicas para comprender mejor las características de los datos.

# %%
df.describe().T
# Out:
#                                 count        mean         std        min  \
# Transaction ID                 1000.0  500.500000  288.819436   1.000000
# Age                            1000.0   41.392000   13.681430  18.000000
# Quantity                       1000.0    2.514000    1.132734   1.000000
# Price per Unit                 1000.0  179.890000  189.681356  25.000000
# Total Amount                   1000.0  456.000000  559.997632  25.000000
# Calculated Total Amount        1000.0  456.000000  559.997632  25.000000
# Total Amount Stdev Difference  1000.0  496.319048  279.006281  40.002368
#
#                                       25%         50%         75%          max
# Transaction ID                 250.750000  500.500000  750.250000  1000.000000
# Age                             29.000000   42.000000   53.000000    64.000000
# Quantity                         1.000000    3.000000    4.000000     4.000000
# Price per Unit                  30.000000   50.000000  300.000000   500.000000
# Total Amount                    60.000000  135.000000  900.000000  2000.000000
# Calculated Total Amount         60.000000  135.000000  900.000000  2000.000000
# Total Amount Stdev Difference  359.997632  469.997632  529.997632  1440.002368

# %% [markdown]
# Calculamos el coeficiente de variación para determinar si los promedios son útiles.

# %%
from eda_utils import obtener_estadisticas_descriptivas_df_es


df_estadisticas = obtener_estadisticas_descriptivas_df_es(df, 2)
df_estadisticas.T
# Out:
#                                Cantidad  Mínimo  Máximo  Promedio  \
# Transaction ID                   1000.0     1.0  1000.0    500.50
# Age                              1000.0    18.0    64.0     41.39
# Quantity                         1000.0     1.0     4.0      2.51
# Price per Unit                   1000.0    25.0   500.0    179.89
# Total Amount                     1000.0    25.0  2000.0    456.00
# Calculated Total Amount          1000.0    25.0  2000.0    456.00
# Total Amount Stdev Difference    1000.0    40.0  1440.0    496.32
#
#                                Desviación Estándar  Mediana  \
# Transaction ID                              288.82    500.5
# Age                                          13.68     42.0
# Quantity                                      1.13      3.0
# Price per Unit                              189.68     50.0
# Total Amount                                560.00    135.0
# Calculated Total Amount                     560.00    135.0
# Total Amount Stdev Difference               279.01    470.0
#
#                                Coeficiente de Variación
# Transaction ID                                     0.58
# Age                                                0.33
# Quantity                                           0.45
# Price per Unit                                     1.05
# Total Amount                                       1.23
# Calculated Total Amount                            1.23
# Total Amount Stdev Difference                      0.56

# %% [markdown]
# Se puede notar que ninguna columna tiene un promedio útil si tenemos en cuenta que el coeficiente de variación de todas las columnas es mayor al 30% (0.30)

# %% [markdown]
# #### Utiliza histogramas y boxplots para visualizar la distribución de las variables numéricas clave.

# %% [markdown]
# ##### Histogramas

# %%
from eda_utils import obtener_columnas_numericas_df, graficar_histogramas

columnas_numericas = obtener_columnas_numericas_df(df)

graficar_histogramas(df, columnas_numericas)

# %% [markdown]
# ##### Boxplots

# %%
from eda_utils import graficar_boxplots

print(columnas_numericas)

graficar_boxplots(df, columnas_numericas)
# Out:
# ['Transaction ID', 'Age', 'Quantity', 'Price per Unit', 'Total Amount', 'Calculated Total Amount', 'Total Amount Stdev Difference']

# %% [markdown]
# #### Crea gráficos de líneas para mostrar las tendencias de ventas a lo largo del tiempo.

# %%
import matplotlib.pyplot as plt


df["Date"] = pd.to_datetime(df["Date"])

df.sort_values(by="Date", inplace=True)

tiempos = pd.to_datetime(df["Date"])
ventas = df["Total Amount"]

plt.plot(tiempos, ventas)
plt.xlabel("Fechas")
plt.ylabel("Monto Total")
plt.show()

# %% [markdown]
# Se puede notar que hay una distribución muy desigual de ventas por día. Por lo cual, sería interesante agrupar solo por mes y ver la evolución de las ventas totales.

# %%
def obtener_anho_mes(x):
    year = str(x["Date"].year)
    month = str(x["Date"].month).zfill(2)

    return pd.to_datetime(f"{year}-{month}-01")


df["Year_Month"] = df.apply(obtener_anho_mes, axis=1)

df_agrupado_suma_fechas = df.groupby("Year_Month")["Total Amount"].sum("Total Amount").reset_index()

df_agrupado_suma_fechas.head(12)
# Out:
#    Year_Month  Total Amount
# 0  2023-01-01         35450
# 1  2023-02-01         44060
# 2  2023-03-01         28990
# 3  2023-04-01         33870
# 4  2023-05-01         53150
# 5  2023-06-01         36715
# 6  2023-07-01         35465
# 7  2023-08-01         36960
# 8  2023-09-01         23620
# 9  2023-10-01         46580
# 10 2023-11-01         34920
# 11 2023-12-01         44690

# %%
fechas = df_agrupado_suma_fechas["Year_Month"]
sumas = df_agrupado_suma_fechas["Total Amount"]

plt.figure(figsize=(7, 5))
plt.plot(fechas, sumas)
plt.xlabel("Fechas")
plt.ylabel("Recaudación")
plt.title("Recaudación por Mes")
plt.show()

# %% [markdown]
# Se procede también a graficar las cantidades de venta mensuales.

# %%
df_agrupado_cant_fechas = df.groupby("Year_Month")["Total Amount"].count().reset_index()

df_agrupado_cant_fechas.head(12)
# Out:
#    Year_Month  Total Amount
# 0  2023-01-01            76
# 1  2023-02-01            85
# 2  2023-03-01            73
# 3  2023-04-01            86
# 4  2023-05-01           105
# 5  2023-06-01            77
# 6  2023-07-01            72
# 7  2023-08-01            94
# 8  2023-09-01            65
# 9  2023-10-01            96
# 10 2023-11-01            78
# 11 2023-12-01            91

# %%
fechas = df_agrupado_cant_fechas["Year_Month"]
cantidades = df_agrupado_cant_fechas["Total Amount"]

plt.figure(figsize=(7, 5))
plt.plot(fechas, cantidades)
plt.xlabel("Fechas")
plt.ylabel("Cant. Ventas")
plt.title("Cant. Ventas por Mes")
plt.show()

# %% [markdown]
# ##### Utiliza gráficos de dispersión para analizar la relación entre diferentes variables.

# %% [markdown]
# Gráfico de dispersión analizando Edad de cliente vs venta total

# %%
plt.scatter(df["Age"], df["Total Amount"])
plt.xlabel("Edad")
plt.ylabel("Monto Total")
plt.show()

# %% [markdown]
# Como se puede ver, no hay mucha relación entre ambas columnas.

# %% [markdown]
# A continuación, se investiga la dispersión de la columna de precio por unidad vs cantidad adquirida.

# %%
plt.scatter(df["Total Amount"], df["Quantity"])
plt.xlabel("Monto Total")
plt.ylabel("Cant. Adquirida")
plt.show()

# %% [markdown]
# ##### Combina histogramas y boxplots para visualizar la distribución de las ventas y detectar valores atípicos.

# %%
from eda_utils import graficar_histograma_y_boxplot

graficar_histograma_y_boxplot(df["Total Amount"], "Total Amount")

# %% [markdown]
# De ambos gráficos, se puede notar que la mayoría de ventas se concentra entre un total de 0 a 1000 usd, siendo valores superiores anómalos.

# %% [markdown]
# Para visualizar mejor, se grafica un histograma con rango intercuartílico.

# %%
from eda_utils import graficar_histograma_con_datos_intercuartiles

graficar_histograma_con_datos_intercuartiles(
    df,
    "Total Amount",
    "Ventas Totales",
    title="Distribución de Ventas",
    figsize=(13, 5),
)

# %% [markdown]
# ## Resolución Parte V

# %% [markdown]
# #### Realiza un análisis de correlación y crea un mapa de calor para visualizar las relaciones entre las variables.

# %%
columnas_de_interes = ["Age", "Price per Unit", "Quantity", "Total Amount"]

# Cálculo de la correlación de Pearson
correlation_matrix = df[[*columnas_de_interes]].corr(method='pearson')
print(correlation_matrix)

# Cálculo de la correlación de Spearman
spearman_corr = df[[*columnas_de_interes]].corr(method='spearman')
print(spearman_corr)

# Cálculo de la correlación de Kendall
kendall_corr = df[[*columnas_de_interes]].corr(method='kendall')
print(kendall_corr)
# Out:
#                      Age  Price per Unit  Quantity  Total Amount
# Age             1.000000       -0.038423 -0.023737     -0.060568
# Price per Unit -0.038423        1.000000  0.017501      0.851925
# Quantity       -0.023737        0.017501  1.000000      0.373707
# Total Amount   -0.060568        0.851925  0.373707      1.000000
#                      Age  Price per Unit  Quantity  Total Amount
# Age             1.000000       -0.037966 -0.023472     -0.037864
# Price per Unit -0.037966        1.000000  0.024014      0.857439
# Quantity       -0.023472        0.024014  1.000000      0.474103
# Total Amount   -0.037864        0.857439  0.474103      1.000000
#                      Age  Price per Unit  Quantity  Total Amount
# Age             1.000000       -0.027979 -0.017853     -0.026288
# Price per Unit -0.027979        1.000000  0.019210      0.724707
# Quantity       -0.017853        0.019210  1.000000      0.401932
# Total Amount   -0.026288        0.724707  0.401932      1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un mapa de calor para la matriz de correlación de Pearson
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Mapa de Calor de la Correlación de Pearson")
plt.show()

# Crear un mapa de calor para la matriz de correlación de Spearman
plt.figure(figsize=(10, 8))
sns.heatmap(spearman_corr, annot=True, cmap='viridis', center=0)
plt.title("Mapa de Calor de la Correlación de Spearman")
plt.show()

# Crear un mapa de calor para la matriz de correlación de Kendall
plt.figure(figsize=(10, 8))
sns.heatmap(kendall_corr, annot=True, cmap='plasma', center=0)
plt.title("Mapa de Calor de la Correlación de Kendall")
plt.show()

# %% [markdown]
# Como se ve en los mapas de correlación, solo las columnas cantidad, precio por unidad, y monto total, parecen tener una correlación. Pero estas columnas son calculadas usando la cantidad y precio por unidad, por lo que es normal que exista una correlación. Para las demás, no se ve una correlación aparente.

# %% [markdown]
# #### Crea subplots para comparar diferentes variables clave.

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Gráfico de dispersión
sns.scatterplot(data=df, x='Age', y='Total Amount', hue='Product Category', ax=axs[0, 0])
axs[0, 0].set_title('Total Amount vs Edad')

# Gráfico de barras
sns.barplot(data=df, x='Product Category', y='Total Amount', hue='Gender', ax=axs[0, 1])
axs[0, 1].set_title('Total Amount por Categoría de Producto y Género')

# Gráfico de cajas
sns.boxplot(data=df, x='Product Category', y='Total Amount', hue='Gender', ax=axs[1, 0])
axs[1, 0].set_title('Distribución de Total Amount por Categoría de Producto y Género')

# Histograma
sns.histplot(data=df, x='Total Amount', kde=True, ax=axs[1, 1])
axs[1, 1].set_title('Histograma de Total Amount')

# Ajustar la posición de los subplots para evitar superposición
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Añade cuadrículas, leyendas, anotaciones y flechas a tus gráficos para mejorar la claridad y la información.

# %%
# Definir el umbral de ventas
umbral_edad = 25
df_filtrado = df[(df['Age'] > umbral_edad)]
# Mostrar cuántos ventas cumplen con el criterio
print(f"Número de ventas con edad > {umbral_edad}: {df_filtrado.shape[0]}")
df_scatter = df_filtrado[['Age', 'Total Amount', 'Product Category']].dropna()
# Configurar el tamaño de la figura
plt.figure(figsize=(12, 8))
# Crear el diagrama de dispersión usando seaborn
sns.scatterplot(
    x='Age',
    y='Total Amount',
    data=df_scatter,
    hue='Product Category',
    palette='viridis',    # Esquema de colores
    alpha=0.7,            # Transparencia de los puntos
    edgecolor=None        # Sin borde en los puntos
)
# Añadir una línea de regresión
sns.regplot(
    x='Age',
    y='Total Amount',
    data=df_scatter,
    scatter=False,
    color='red',
    line_kws={'linewidth': 2}
)
# Añadir títulos y etiquetas
plt.title('Relación entre Edad y Ventas', fontsize=16)
plt.xlabel('Edad', fontsize=14)
plt.ylabel('Ventas', fontsize=14)
# Ajustar el layout para evitar superposiciones
plt.tight_layout()
# Mostrar el gráfico
plt.show()
# Out:
# Número de ventas con edad > 25: 831

# %% [markdown]
# #### Análisis de datos agrupados.

# %% [markdown]
# Obtenemos los totales de ventas por categoría y graficamos.

# %%
df_agrupado_suma_categorias = df.groupby("Product Category")["Total Amount"].sum("Total Amount").reset_index().sort_values("Total Amount", ascending=False)

df_agrupado_suma_categorias
# Out:
#   Product Category  Total Amount
# 2      Electronics        156905
# 1         Clothing        155580
# 0           Beauty        143515

# %%
plt.figure(figsize=(7, 5))
sns.barplot(
    df_agrupado_suma_categorias,
    x='Product Category',
    y='Total Amount',
    hue='Product Category',
)
plt.ylabel('Totales')
plt.xlabel("Categoría de Producto")
plt.title('Recaudación por Categoría')
plt.show()

# %% [markdown]
# Obtenemos las cantidades de ventas por categoría y graficamos.

# %%
df_agrupado_cant_categorias = df.groupby("Product Category")["Total Amount"].count().reset_index().sort_values("Total Amount", ascending=False)

df_agrupado_cant_categorias
# Out:
#   Product Category  Total Amount
# 1         Clothing           351
# 2      Electronics           342
# 0           Beauty           307

# %%
plt.figure(figsize=(7, 5))
sns.barplot(
    df_agrupado_cant_categorias,
    x='Product Category',
    y='Total Amount',
    hue='Product Category',
)
plt.ylabel('Cantidades')
plt.xlabel("Categoría de Producto")
plt.title('Cantidades de ventas por Categoría')
plt.show()

# %%
df_agrupado_sum_categorias_generos = df.groupby(
    by=["Product Category", "Gender"])[
        ["Total Amount"]
    ].sum("Total Amount").reset_index().sort_values(
        "Total Amount",
        ascending=False
    )

df_agrupado_sum_categorias_generos
# Out:
#   Product Category  Gender  Total Amount
# 2         Clothing  Female         81275
# 5      Electronics    Male         80170
# 4      Electronics  Female         76735
# 0           Beauty  Female         74830
# 3         Clothing    Male         74305
# 1           Beauty    Male         68685

# %% [markdown]
# Graficamos totales por Categoría y Género

# %%
plt.figure(figsize=(7, 5))
sns.barplot(
    df_agrupado_sum_categorias_generos,
    x='Product Category',
    y='Total Amount',
    hue='Gender',
)
plt.title("Recaudación por Categoría y Género")
plt.ylabel("Monto")
plt.xlabel("Categoría de Producto")
plt.legend(framealpha=0.3)
plt.show()

# %%
df_agrupado_cant_categorias_generos = df.groupby(by=["Product Category", "Gender"])[["Total Amount"]].count().reset_index().sort_values("Total Amount", ascending=False)

df_agrupado_cant_categorias_generos
# Out:
#   Product Category  Gender  Total Amount
# 3         Clothing    Male           177
# 2         Clothing  Female           174
# 5      Electronics    Male           172
# 4      Electronics  Female           170
# 0           Beauty  Female           166
# 1           Beauty    Male           141

# %% [markdown]
# Graficamos cantidades por Categoría y Género

# %%
plt.figure(figsize=(7, 5))
sns.barplot(
    df_agrupado_cant_categorias_generos,
    x='Product Category',
    y='Total Amount',
    hue='Gender',
)
plt.xlabel("Categoría de Producto")
plt.ylabel("Cantidad de Ventas")
plt.title("Cantidades de Ventas por Categoría y Género")
plt.legend(framealpha=0.3)
plt.show()

# %% [markdown]
# Realizamos un análisis similar para verificar las dispersiones de edad pero por categoría y por género.

# %%
df_agrupado_cant_edades_categorias = df.groupby(
    by=["Age", "Product Category"])[["Total Amount"]].count().reset_index().sort_values(
        "Total Amount",
        ascending=False
    )

df_agrupado_cant_edades_categorias.head(10)
# Out:
#      Age Product Category  Total Amount
# 101   51      Electronics            14
# 139   64         Clothing            13
# 84    46           Beauty            13
# 41    31      Electronics            13
# 76    43         Clothing            13
# 98    50      Electronics            12
# 48    34           Beauty            12
# 36    30           Beauty            12
# 134   62      Electronics            12
# 77    43      Electronics            12

# %%
sns.scatterplot(
    x='Age',
    y='Total Amount',
    data=df_agrupado_cant_edades_categorias,
    hue='Product Category',
    palette='viridis',    # Esquema de colores
    alpha=0.7,            # Transparencia de los puntos
    edgecolor=None        # Sin borde en los puntos
)
# Añadir una línea de regresión
sns.regplot(
    x='Age',
    y='Total Amount',
    data=df_agrupado_cant_edades_categorias,
    scatter=False,
    color='red',
    line_kws={'linewidth': 2}
)
plt.ylabel("Cant. de ventas")
# Out:
# Text(0, 0.5, 'Cant. de ventas')

# %% [markdown]
# Realizamos el mismo análisis pero por género.

# %%
df_agrupado_cant_edades_genero = df.groupby(
    by=["Age", "Gender"])[["Total Amount"]].count().reset_index().sort_values(
    "Total Amount",
    ascending=False
)

df_agrupado_cant_edades_genero.head(10)
# Out:
#     Age  Gender  Total Amount
# 92   64  Female            19
# 50   43  Female            19
# 73   54    Male            17
# 66   51  Female            17
# 27   31    Male            16
# 89   62    Male            16
# 79   57    Male            16
# 56   46  Female            16
# 48   42  Female            15
# 16   26  Female            15

# %%
sns.scatterplot(
    x='Age',
    y='Total Amount',
    data=df_agrupado_cant_edades_genero,
    hue='Gender',
    palette='viridis',    # Esquema de colores
    alpha=0.7,            # Transparencia de los puntos
    edgecolor=None        # Sin borde en los puntos
)
# Añadir una línea de regresión
sns.regplot(
    x='Age',
    y='Total Amount',
    data=df_agrupado_cant_edades_genero,
    scatter=False,
    color='red',
    line_kws={'linewidth': 2}
)
# Out:
# <Axes: xlabel='Age', ylabel='Total Amount'>

# %%
df_agrupado_cant_edades_genero_categoria = df.groupby(
    by=["Age", "Gender", "Product Category"])[["Total Amount"]].count().reset_index().sort_values(
    "Total Amount",
    ascending=False
)

df_agrupado_cant_edades_genero_categoria.head()
# Out:
#      Age  Gender Product Category  Total Amount
# 269   64  Female         Clothing            10
# 81    31    Male      Electronics             9
# 73    30    Male           Beauty             8
# 261   62    Male      Electronics             8
# 192   50    Male      Electronics             8

# %% [markdown]
# Se agregan también gráficos para ver la evolución de las ventas por categoría.

# %%
df_agrupado_ventas_fecha_categoria = df.groupby(["Year_Month", "Product Category"])["Total Amount"].sum().reset_index()

df_agrupado_ventas_fecha_categoria.head(12)
# Out:
#    Year_Month Product Category  Total Amount
# 0  2023-01-01           Beauty         12430
# 1  2023-01-01         Clothing         13125
# 2  2023-01-01      Electronics          9895
# 3  2023-02-01           Beauty         14035
# 4  2023-02-01         Clothing         14560
# 5  2023-02-01      Electronics         15465
# 6  2023-03-01           Beauty         10545
# 7  2023-03-01         Clothing         15065
# 8  2023-03-01      Electronics          3380
# 9  2023-04-01           Beauty         11905
# 10 2023-04-01         Clothing         13940
# 11 2023-04-01      Electronics          8025

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(df_agrupado_ventas_fecha_categoria, x="Year_Month", y="Total Amount", hue="Product Category")
plt.xlabel("Fecha")
plt.ylabel("Ventas")
plt.title("Recaudación por Mes")
plt.legend()
plt.show()

# %% [markdown]
# También graficamos cantidades vendidas a lo largo del tiempo por producto.

# %%
df_agrupado_cant_fecha_categoria = df.groupby(["Year_Month", "Product Category"])["Total Amount"].count().reset_index()

df_agrupado_cant_fecha_categoria.head(12)
# Out:
#    Year_Month Product Category  Total Amount
# 0  2023-01-01           Beauty            25
# 1  2023-01-01         Clothing            26
# 2  2023-01-01      Electronics            25
# 3  2023-02-01           Beauty            26
# 4  2023-02-01         Clothing            33
# 5  2023-02-01      Electronics            26
# 6  2023-03-01           Beauty            21
# 7  2023-03-01         Clothing            38
# 8  2023-03-01      Electronics            14
# 9  2023-04-01           Beauty            29
# 10 2023-04-01         Clothing            36
# 11 2023-04-01      Electronics            21

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(df_agrupado_cant_fecha_categoria, x="Year_Month", y="Total Amount", hue="Product Category")
plt.xlabel("Fecha")
plt.ylabel("Cantidad")
plt.title("Cantidad de Ventas por Mes")
plt.legend()
plt.show()

# %% [markdown]
# Graficamos boxplots para observar las distribuciones de ventas por categoría.

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(
    df,
    x="Product Category",
    y="Total Amount",
    hue="Gender",
)
plt.ylabel("Monto de Venta")
plt.xlabel("Categoría")
plt.legend()
plt.show()

# %% [markdown]
# Graficamos un histograma del total de ventas con rangos intercuartiles.

# %%
import numpy as np

Q1 = np.percentile(df["Total Amount"], 25)
Q2 = np.percentile(df["Total Amount"], 50)
Q3 = np.percentile(df["Total Amount"], 75)
IQR = Q3 - Q1

plt.figure(figsize=(15, 10))
plt.hist(df["Total Amount"], bins=20, color='skyblue', edgecolor='black', alpha=0.7)

plt.axvline(Q1, color='orange', linestyle='dashed', linewidth=2, label=f'Q1 ({Q1:.2f})')
plt.axvline(Q2, color='red', linestyle='dashed', linewidth=2, label=f'Q2 ({Q1:.2f})')
plt.axvline(Q3, color='purple', linestyle='dashed', linewidth=2, label=f'Q3 ({Q3:.2f})')
plt.axvspan(Q1, Q3, color='gray', alpha=0.3, label=f'IQR ({IQR:.2f})')

plt.xlabel('Monto')
plt.ylabel('Frecuencia')
plt.title('Histograma con índice intercuartil')
plt.legend()
plt.show()

# %% [markdown]
# Graficamos Ventas por Rango Etario.

# %%
# Rangos etarios obtenidos de este sitio: https://www.palbin.com/es/blog/p1009-que-edad-tienen-tus-compradores-plan-de-marketing-digital.html
def obtener_rango_etario(x):
    if 0 <= x < 18:
        return "0-18"

    if 18 <= x < 25:
        return "18-25"

    if 25 <= x < 40:
        return "25-40"

    if 40 <= x < 65:
        return "40-65"
    
    return "65+"


df["Age_Range"] = df["Age"].apply(obtener_rango_etario)

df.head()
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 521             522 2023-01-01     CUST522    Male   46           Beauty
# 179             180 2023-01-01     CUST180    Male   41         Clothing
# 558             559 2023-01-01     CUST559  Female   40         Clothing
# 302             303 2023-01-02     CUST303    Male   19      Electronics
# 978             979 2023-01-02     CUST979  Female   19           Beauty
#
#      Quantity  Price per Unit  Total Amount  Calculated Total Amount  \
# 521         3             500          1500                     1500
# 179         3             300           900                      900
# 558         4             300          1200                     1200
# 302         3              30            90                       90
# 978         1              25            25                       25
#
#     Sale Classification  Total Amount Stdev Difference Year_Month Age_Range
# 521                Alta                     940.002368 2023-01-01     40-65
# 179               Media                     340.002368 2023-01-01     40-65
# 558               Media                     640.002368 2023-01-01     40-65
# 302                Baja                     469.997632 2023-01-01     18-25
# 978                Baja                     534.997632 2023-01-01     18-25

# %%
df_agrupado_sum_edades = df.groupby(
    by=["Product Category", "Age_Range"])[
        ["Total Amount"]
    ].sum("Total Amount").reset_index().sort_values(
        "Age_Range",
        ascending=True
    )

plt.figure(figsize=(7, 5))
sns.barplot(
    df_agrupado_sum_edades,
    x="Age_Range",
    y="Total Amount",
    hue="Product Category",
)
plt.title("Recaudación por Categoría y Edad.", fontsize=16)
plt.xlabel("Edad", fontsize=14)
plt.ylabel('Recaudación', fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
# Graficamos también las cantidades de ventas por edad.

# %%
df_agrupado_cant_edades = df.groupby(
    by=["Product Category", "Age_Range"])[
        ["Total Amount"]
    ].count().reset_index().sort_values(
        "Age_Range",
        ascending=True
    )

plt.figure(figsize=(7, 5))
sns.barplot(
    df_agrupado_cant_edades,
    x="Age_Range",
    y="Total Amount",
    hue="Product Category",
)
plt.title("Recaudación por Categoría y Edad.", fontsize=16)
plt.xlabel("Edad", fontsize=14)
plt.ylabel('Cantidad de Ventas', fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
# ### Realizar una Presentación: Prepara una presentación en slides que resuma tu análisis y visualizaciones

# %% [markdown]
# Presentación disponible [aquí](https://docs.google.com/presentation/d/17Hl57ASKbZUh0srr89pYQMWzQypOKMEM/edit#slide=id.g2d4d53581d4_0_176)
